# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from scipy.stats import bootstrap

# %%
data_MCTS_Highest = pd.read_csv("results/MCTSAgent-HighestAgent.csv")
scores_MCTS_Highest = data_MCTS_Highest['MCTSAgent']

data_MCTS_Lowest = pd.read_csv("results/MCTSAgent-LowestAgent.csv")
scores_MCTS_Lowest = data_MCTS_Highest['MCTSAgent']

data_MCTS_Simple = pd.read_csv("results/MCTSAgent-SimpleAgent.csv")
scores_MCTS_Simple = data_MCTS_Simple['MCTSAgent']

data_MCTS_Smart = pd.read_csv("results/MCTSAgent-SmartAgent.csv")
scores_MCTS_Smart = data_MCTS_Smart['MCTSAgent']

data_MCTS_Random = pd.read_csv("results/MCTSAgent-RandomAgent.csv")
scores_MCTS_Random = data_MCTS_Random['MCTSAgent']

data_Lowest_Highest = pd.read_csv("results/LowestAgent-HighestAgent.csv")
scores_Lowest_Highest = data_Lowest_Highest['LowestAgent']

data_Lowest_Random = pd.read_csv("results/LowestAgent-RandomAgent.csv")
scores_Lowest_Random = data_Lowest_Highest['LowestAgent']

data_Lowest_Simple = pd.read_csv("results/LowestAgent-SimpleAgent.csv")
scores_Lowest_Simple = data_Lowest_Simple['LowestAgent']

data_Lowest_Smart = pd.read_csv("results/LowestAgent-SmartAgent.csv")
scores_Lowest_Smart = data_Lowest_Smart['LowestAgent']

data_MCTSSmart_Smart_Time_0_1 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_1.csv")
scores_MCTSSmart_Smart_Time_0_1 = data_MCTSSmart_Smart_Time_0_1['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_0_2 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_2.csv")
scores_MCTSSmart_Smart_Time_0_2 = data_MCTSSmart_Smart_Time_0_2['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_0_3 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_3.csv")
scores_MCTSSmart_Smart_Time_0_3 = data_MCTSSmart_Smart_Time_0_3['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_0_4 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_4.csv")
scores_MCTSSmart_Smart_Time_0_4 = data_MCTSSmart_Smart_Time_0_4['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_0_5 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_5.csv")
scores_MCTSSmart_Smart_Time_0_5 = data_MCTSSmart_Smart_Time_0_5['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_0_6 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_6.csv")
scores_MCTSSmart_Smart_Time_0_6 = data_MCTSSmart_Smart_Time_0_6['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_0_7 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_7.csv")
scores_MCTSSmart_Smart_Time_0_7 = data_MCTSSmart_Smart_Time_0_7['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_0_8 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_8.csv")
scores_MCTSSmart_Smart_Time_0_8 = data_MCTSSmart_Smart_Time_0_8['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_0_9 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_9.csv")
scores_MCTSSmart_Smart_Time_0_9 = data_MCTSSmart_Smart_Time_0_9['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_1 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_1.csv")
scores_MCTSSmart_Smart_Time_1 = data_MCTSSmart_Smart_Time_1['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_2 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_2.csv")
scores_MCTSSmart_Smart_Time_2 = data_MCTSSmart_Smart_Time_2['MCTSAgent_Smart']

data_MCTSSmart_Smart_Time_0_1_EXP_1_OVER_SQRT_2 = pd.read_csv(
    "results/MCTSAgent-Smart-SmartAgent-EXP_1_over_Sqrt_2-MAX_DEPTH_55-Time_0_point_1.csv")
scores_MCTSSmart_Smart_Time_0_1_EXP_1_OVER_SQRT_2 = data_MCTSSmart_Smart_Time_0_1_EXP_1_OVER_SQRT_2['MCTSAgent_Smart']


## Agents Tournament
### Simple Agent:
data_SimpleAgent_HighestAgent = pd.read_csv("results/SimpleAgent-HighestAgent.csv")
scores_SimpleAgent_HighestAgent = data_SimpleAgent_HighestAgent['SimpleAgent']

data_SimpleAgent_LowestAgent = pd.read_csv("results/SimpleAgent-LowestAgent.csv")
scores_SimpleAgent_LowestAgent = data_SimpleAgent_LowestAgent['SimpleAgent']

data_SimpleAgent_RandomAgent = pd.read_csv("results/SimpleAgent-RandomAgent.csv")
scores_SimpleAgent_RandomAgent = data_SimpleAgent_RandomAgent['SimpleAgent']

data_SimpleAgent_SmartAgent = pd.read_csv("results/SimpleAgent-SmartAgent.csv")
scores_SimpleAgent_SmartAgent = data_SimpleAgent_SmartAgent['SimpleAgent']

### Highest Agent:#
data_HighestAgent_SimpleAgent = pd.read_csv("results/HighestAgent-SimpleAgent.csv")
scores_HighestAgent_SimpleAgent = data_HighestAgent_SimpleAgent['HighestAgent']

data_HighestAgent_LowestAgent = pd.read_csv("results/HighestAgent-LowestAgent.csv")
scores_HighestAgent_LowestAgent = data_HighestAgent_LowestAgent['HighestAgent']

data_HighestAgent_RandomAgent = pd.read_csv("results/HighestAgent-RandomAgent.csv")
scores_HighestAgent_RandomAgent = data_HighestAgent_RandomAgent['HighestAgent']

data_HighestAgent_SmartAgent = pd.read_csv("results/HighestAgent-SmartAgent.csv")
scores_HighestAgent_SmartAgent = data_HighestAgent_SmartAgent['HighestAgent']

### Lowest Agent:
data_LowestAgent_SimpleAgent = pd.read_csv("results/LowestAgent-SimpleAgent.csv")
scores_LowestAgent_SimpleAgent = data_LowestAgent_SimpleAgent['LowestAgent']

data_LowestAgent_HighestAgent = pd.read_csv("results/LowestAgent-HighestAgent.csv")
scores_LowestAgent_HighestAgent = data_LowestAgent_HighestAgent['LowestAgent']

data_LowestAgent_RandomAgent = pd.read_csv("results/LowestAgent-RandomAgent.csv")
scores_LowestAgent_RandomAgent = data_LowestAgent_RandomAgent['LowestAgent']

data_LowestAgent_SmartAgent = pd.read_csv("results/LowestAgent-SmartAgent.csv")
scores_LowestAgent_SmartAgent = data_LowestAgent_SmartAgent['LowestAgent']

### Random Agent:
data_RandomAgent_SimpleAgent = pd.read_csv("results/RandomAgent-SimpleAgent.csv")
scores_RandomAgent_SimpleAgent = data_RandomAgent_SimpleAgent['RandomAgent']

data_RandomAgent_HighestAgent = pd.read_csv("results/RandomAgent-HighestAgent.csv")
scores_RandomAgent_HighestAgent = data_RandomAgent_HighestAgent['RandomAgent']

data_RandomAgent_LowestAgent = pd.read_csv("results/RandomAgent-LowestAgent.csv")
scores_RandomAgent_LowestAgent = data_RandomAgent_LowestAgent['RandomAgent']

data_RandomAgent_SmartAgent = pd.read_csv("results/RandomAgent-SmartAgent.csv")
scores_RandomAgent_SmartAgent = data_RandomAgent_SmartAgent['RandomAgent']

### Smart Agent:
data_SmartAgent_SimpleAgent = pd.read_csv("results/SmartAgent-SimpleAgent.csv")
scores_SmartAgent_SimpleAgent = data_SmartAgent_SimpleAgent['SmartAgent']

data_SmartAgent_HighestAgent = pd.read_csv("results/SmartAgent-HighestAgent.csv")
scores_SmartAgent_HighestAgent = data_SmartAgent_HighestAgent['SmartAgent']

data_SmartAgent_LowestAgent = pd.read_csv("results/SmartAgent-LowestAgent.csv")
scores_SmartAgent_LowestAgent = data_SmartAgent_LowestAgent['SmartAgent']

data_SmartAgent_RandomAgent = pd.read_csv("results/SmartAgent-RandomAgent.csv")
scores_SmartAgent_RandomAgent = data_SmartAgent_RandomAgent['SmartAgent']

# ANN Agent

data_MCTSANN_MCTS = pd.read_csv("results/MCTSAgent_ANN_2Seconds-MCTSAgent_Basic_1Second.csv")
scores_MCTSANN_MCTS = data_MCTSANN_MCTS['MCTSAgent_ANN']

# %%
means = [np.mean(scores_MCTS_Highest),np.mean(scores_MCTS_Lowest),np.mean(scores_MCTS_Random),np.mean(scores_MCTS_Simple),np.mean(scores_MCTS_Smart)]
result = bootstrap((scores_MCTS_Highest,),statistic=np.mean,n_resamples=99999)
ci_random = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_random}")

result = bootstrap((scores_MCTS_Lowest,),statistic=np.mean,n_resamples=99999)
ci_12 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_12}")

result = bootstrap((scores_MCTS_Random,),statistic=np.mean,n_resamples=99999)
ci_smart = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_smart}")

result = bootstrap((scores_MCTS_Simple,),statistic=np.mean,n_resamples=99999)
ci_4 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_4}")

result = bootstrap((scores_MCTS_Smart,),statistic=np.mean,n_resamples=99999)
ci_5 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_5}")

x_values = np.arange(len(means))
# Confidence intervals for the y-axis
cis = [ci_random, ci_12, ci_smart, ci_4, ci_5]

# Plot the confidence intervals
plt.figure(figsize=(6, 4))

for i, ci in enumerate(cis):
    plt.plot([i, i], ci, marker='_', color='grey', markersize=8, linewidth=2)

plt.scatter(x_values, means, color='black', marker='o')

plt.xticks(x_values, ['Highest Agent', 'Lowest Agent', 'Random Agent', 'Simple Agent', 'Smart Agent'])
plt.xlabel('Agent Type')
plt.ylabel('Average Score')
plt.axhline(y=6.5, color='green', linestyle='--', label='Avg = 6.5')
plt.title('Performance of MCTS against Agent Types')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=2.475, high=2.965)
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=2.476, high=2.964)
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=2.9691542288557216, high=3.5980099502487564)
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=3.457, high=4.202)
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=6.824, high=7.702)

# %%
data_new_mcts_0_1 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_1.csv")
score_new_mcts_0_1 = data_new_mcts_0_1['MCTSAgent_Smart']

data_new_mcts_0_2 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_2.csv")
score_new_mcts_0_2 = data_new_mcts_0_2['MCTSAgent_Smart']

data_new_mcts_0_5 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_0_point_5.csv")
score_new_mcts_0_5 = data_new_mcts_0_5['MCTSAgent_Smart']

data_new_mcts_1 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_1.csv")
score_new_mcts_1 = data_new_mcts_1['MCTSAgent_Smart']

data_new_mcts_2 = pd.read_csv("results/MCTSAgent-Smart-SmartAgent-EXP_2-MAX_DEPTH_55-Time_2.csv")
score_new_mcts_2 = data_new_mcts_2['MCTSAgent_Smart']

data_new_mcts_3 = pd.read_csv("results/MCTSAgent_Smart-SmartAgent.csv")
score_new_mcts_3 = data_new_mcts_3['MCTSAgent_Smart']

mean_new_mcts_0_1 = np.mean(score_new_mcts_0_1)
mean_new_mcts_0_2 = np.mean(score_new_mcts_0_2)
mean_new_mcts_0_5 = np.mean(score_new_mcts_0_5)
mean_new_mcts_1 = np.mean(score_new_mcts_1)
mean_new_mcts_2 = np.mean(score_new_mcts_2)
mean_new_mcts_3 = np.mean(score_new_mcts_3)
#print(mean_new_mcts_0_1)
print(mean_new_mcts_0_2)
print(mean_new_mcts_0_5)
print(mean_new_mcts_1)
print(mean_new_mcts_2)
print(mean_new_mcts_3)

x_values = [0.1, 0.2, 0.5, 1, 2, 3]
means_to_plot = [
    #mean_new_mcts_0_1,
    mean_new_mcts_0_2,
    mean_new_mcts_0_5,
    mean_new_mcts_1,
    mean_new_mcts_2,
    mean_new_mcts_3]


#result = bootstrap((score_new_mcts_0_1,),statistic=np.mean,n_resamples=9999)
#c_0_1 = result.confidence_interval
#print(f"Bootstrap Confidence Interval of the Mean: {c_0_1}")


result = bootstrap((score_new_mcts_0_2,),statistic=np.mean,n_resamples=9999)
c_interval = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {c_interval}")

result = bootstrap((score_new_mcts_0_5,),statistic=np.mean,n_resamples=9999)
c_0_5 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {c_0_5}")

result = bootstrap((score_new_mcts_1,),statistic=np.mean,n_resamples=9999)
c_1 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {c_1}")

result = bootstrap((score_new_mcts_2,),statistic=np.mean,n_resamples=9999)
c_2 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {c_2}")

result = bootstrap((score_new_mcts_3,),statistic=np.mean,n_resamples=9999)
c_3 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {c_3}")

cis = [
    #c_0_1,
    c_interval,
    c_0_5,
    c_1,
    c_2,
    c_3]

plt.figure(figsize=(6, 4))

for i, ci in enumerate(cis):
    plt.plot([i, i], ci, marker='_', color='grey', markersize=8, linewidth=2)

plt.scatter(['0.2', '0.5', '1', '2', '3'], means_to_plot, color='black', marker='o')

plt.axhline(y=6.5, color='green', linestyle='--', label='Avg = 6.5')
plt.xlabel('Time per move')
plt.ylabel('Average score')
plt.legend()
plt.title('MCTS performance over different times per move')
plt.grid(True)
plt.show()
# Out:
# 6.5
# 6.383
# 6.016
# 6.125
# 6.088709677419355
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=6.104, high=6.928)
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=5.98, high=6.809)
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=5.611, high=6.436049556570167)
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=5.706, high=6.557)
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=5.669354838709677, high=6.52116935483871)

# %%
mean_ann = np.mean(scores_MCTSANN_MCTS)

print(mean_ann)

means_to_plot = [mean_ann]


result = bootstrap((scores_MCTSANN_MCTS,),statistic=np.mean,n_resamples=9999)
c_interval = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {c_interval}")

cis = [
    c_interval]

plt.figure(figsize=(4, 4))

for i, ci in enumerate(cis):
    plt.plot([i, i], ci, marker='_', color='grey', markersize=8, linewidth=2)

plt.scatter(['0'], means_to_plot, color='black', marker='o')

plt.axhline(y=6.5, color='green', linestyle='--', label='Avg = 6.5')
plt.ylabel('Average score')
plt.legend()
plt.title('Hybrid MCTS-ANN performance vs normal MCTS')
plt.grid(True)
plt.show()
# Out:
# 6.9296875
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=6.3828125, high=7.5131831900635895)

# %%
# Comparison of MCTS with best performing MCTS SMART
MCTS_Smart_Smart_C_2 = pd.read_csv('results/MCTSAgent_Smart-SmartAgent.csv')

means = [np.mean(scores_MCTS_Smart),np.mean(MCTS_Smart_Smart_C_2['MCTSAgent_Smart'])]
result = bootstrap((scores_MCTS_Smart,),statistic=np.mean,n_resamples=99999)
ci_random = result.confidence_interval
print(means)
print(f"Bootstrap Confidence Interval of the Mean: {ci_random}")

result = bootstrap((MCTS_Smart_Smart_C_2['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
ci_smart = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_smart}")


x_values = np.arange(len(means))
# Confidence intervals for the y-axis
cis = [ci_random, ci_smart]

# Plot the confidence intervals
plt.figure(figsize=(4, 4))

for i, ci in enumerate(cis):
    plt.plot([i, i], ci, marker='_', color='grey', markersize=8, linewidth=2)

plt.scatter(x_values, means, color='black', marker='o')

plt.xticks([0, 1], ['MCTS Random', 'MCTS Smart'])
plt.axis([-0.5, 1.5, 5.5, 8])
plt.xlabel('Agent Type')
plt.ylabel('Average Score')
plt.axhline(y=6.5, color='green', linestyle='--', label='Avg = 6.5')
plt.title('Improvement of MCTS performance against Best Agent')
plt.legend()
plt.grid(True)
# Out:
# [7.253, 6.088709677419355]
# Bootstrap Confidence Interval of the Mean: ConfidenceInterval(low=6.823, high=7.699)

# %%
data_smart = pd.read_csv("results/MCTSAgent-HighestAgent.csv")

scores_MCST = data_smart['MCTSAgent']

np.mean(scores_MCST)
plt.hist(scores_MCST,bins=26, rwidth=0.8)
plt.show()

# %%
data_smart = pd.read_csv("results/MCTSAgent-SimpleAgent.csv")

scores_Simple = data_smart['SimpleAgent']

plt.hist(scores_Simple,bins=26, rwidth=0.8)
plt.show()

# %%
df_c_0_point_1 = pd.read_csv('results/MCTSAgent_Smart-SmartAgent-EXP_0_Point_1-MAX_DEPTH_55.csv')
df_c_2_0 = pd.read_csv('results/MCTSAgent_Smart-SmartAgent.csv')
df_c_1_over_sqrt_2 = pd.read_csv('results/MCTSAgent_Smart-SmartAgent_EXP_2_oneOverSquareRootOfTwo.csv')

mean_c_0_point_1 = df_c_0_point_1['MCTSAgent_Smart'].mean()
variance_c_0_point_1 = df_c_0_point_1['MCTSAgent_Smart'].var()

mean_c_2_0 = df_c_2_0['MCTSAgent_Smart'].mean()
variance_c_2_0 = df_c_2_0['MCTSAgent_Smart'].var()

mean_c_1_over_sqrt_2 = df_c_1_over_sqrt_2['MCTSAgent_Smart'].mean()
variance_c_1_over_sqrt_2 = df_c_1_over_sqrt_2['MCTSAgent_Smart'].var()

print(f'Mean for C=0.1: {mean_c_0_point_1}, Variance: {variance_c_0_point_1}')
print(f'Mean for C=2: {mean_c_2_0}, Variance: {variance_c_2_0}')
print(f'Mean for C=1/Sqrt(2): {mean_c_1_over_sqrt_2}, Variance: {variance_c_1_over_sqrt_2}')

plt.plot(['1/Sqrt(2)', '0.1', '2'], [mean_c_1_over_sqrt_2, mean_c_0_point_1, mean_c_2_0], marker='o')

plt.xlabel('C Constant')
plt.ylabel('Mean Score')
plt.title('Mean Score vs C Constant')
plt.show()
# Out:
# Mean for C=0.1: 6.216, Variance: 43.83718118118118
# Mean for C=2: 6.088709677419355, Variance: 45.971941017545
# Mean for C=1/Sqrt(2): 5.86, Variance: 39.74614614614615

# %%
means = [np.mean(df_c_0_point_1['MCTSAgent_Smart']),np.mean(df_c_1_over_sqrt_2['MCTSAgent_Smart']),np.mean(df_c_2_0['MCTSAgent_Smart'])]
result = bootstrap((df_c_0_point_1['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
ci_random = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_random}")

result = bootstrap((df_c_1_over_sqrt_2['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
ci_12 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_12}")

result = bootstrap((df_c_2_0['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
ci_smart = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_smart}")


x_values = np.arange(len(means))
# Confidence intervals for the y-axis
cis = [ci_random, ci_12, ci_smart]

# Plot the confidence intervals
plt.figure(figsize=(6, 4))

for i, ci in enumerate(cis):
    plt.plot([i, i], ci, marker='_', color='grey', markersize=8, linewidth=2)

plt.scatter(x_values, means, color='black', marker='o')

plt.xticks(x_values, ['0.1', '1/sqrt(2)', '2.0'])
plt.xlabel('Exploration Constant C')
plt.ylabel('Average Score')
plt.axhline(y=6.5, color='green', linestyle='--', label='Avg = 6.5')
plt.title('Impact of Change in Exploration Constant of MCTS')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 means = [np.mean(df_c_0_point_1['MCTSAgent_Smart']),np.mean(df_c_1_over_sqrt_2['MCTSAgent_Smart']),np.mean(df_c_2_0['MCTSAgent_Smart'])]
#       2 result = bootstrap((df_c_0_point_1['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
#       3 ci_random = result.confidence_interval
#
# NameError: name 'df_c_0_point_1' is not defined

# %%
df_depth_55 = pd.read_csv('results/MCTSAgent_Smart-SmartAgent.csv')
df_depth_4 = pd.read_csv('results/MCTSAgent_Smart-SmartAgent-EXP_2-MAX_DEPTH_4.csv')
df_depth_8 = pd.read_csv('results/MCTSAgent_Smart-SmartAgent-EXP_2-MAX_DEPTH_8.csv')
df_depth_12 = pd.read_csv('results/MCTSAgent_Smart-SmartAgent-EXP_2-MAX_DEPTH_12.csv')

mean_depth_55 = df_depth_55['MCTSAgent_Smart'].mean()
variance_depth_55 = df_depth_55['MCTSAgent_Smart'].var()

mean_depth_4 = df_depth_4['MCTSAgent_Smart'].mean()
variance_depth_4 = df_depth_4['MCTSAgent_Smart'].var()

mean_depth_8 = df_depth_8['MCTSAgent_Smart'].mean()
variance_depth_8 = df_depth_8['MCTSAgent_Smart'].var()

mean_depth_12 = df_depth_12['MCTSAgent_Smart'].mean()
variance_depth_12 = df_depth_12['MCTSAgent_Smart'].var()

print(f'Mean for Max Depth=55: {mean_depth_55}, Variance: {variance_depth_55}')
print(f'Mean for Max Depth=4: {mean_depth_4}, Variance: {variance_depth_4}')
print(f'Mean for Max Depth=8: {mean_depth_8}, Variance: {variance_depth_8}')
print(f'Mean for Max Depth=12: {mean_depth_12}, Variance: {variance_depth_12}')

plt.plot(['4', '8', '12', '55'], [mean_depth_4, mean_depth_8, mean_depth_12, mean_depth_55], marker='o')

plt.xlabel('Max Depth')
plt.ylabel('Mean Score')
plt.title('Mean Score vs Max Depth')

plt.show()
# Out:
# Mean for Max Depth=55: 6.088709677419355, Variance: 45.971941017545
# Mean for Max Depth=4: 6.5, Variance: 45.02302302302302
# Mean for Max Depth=8: 6.212, Variance: 44.21126726726727
# Mean for Max Depth=12: 6.151, Variance: 44.98518418418418

# %%
means = [np.mean(df_depth_55['MCTSAgent_Smart']),np.mean(df_depth_12['MCTSAgent_Smart']),np.mean(df_depth_8['MCTSAgent_Smart']),np.mean(df_depth_4['MCTSAgent_Smart'])]
result = bootstrap((df_depth_55['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
ci_random = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_random}")

result = bootstrap((df_depth_12['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
ci_12 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_12}")

result = bootstrap((df_depth_8['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
ci_smart = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_smart}")

result = bootstrap((df_depth_4['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
ci_4 = result.confidence_interval
print(f"Bootstrap Confidence Interval of the Mean: {ci_4}")

x_values = np.arange(4)
# Confidence intervals for the y-axis
cis = [ci_random, ci_12, ci_smart, ci_4]

# Plot the confidence intervals
plt.figure(figsize=(6, 4))

for i, ci in enumerate(cis):
    plt.plot([i, i], ci, marker='_', color='grey', markersize=8, linewidth=2)

plt.scatter(x_values, means, color='black', marker='o')

plt.xticks(x_values, ['No limit', 'Depth 12', 'Depth 8', 'Depth 4'])
plt.xlabel('Depth used')
plt.ylabel('Average Score')
plt.axhline(y=6.5, color='green', linestyle='--', label='Avg = 6.5')
plt.title('Impact of Change in Maximum Depth of MCTS')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 means = [np.mean(df_depth_55['MCTSAgent_Smart']),np.mean(df_depth_12['MCTSAgent_Smart']),np.mean(df_depth_8['MCTSAgent_Smart']),np.mean(df_depth_4['MCTSAgent_Smart'])]
#       2 result = bootstrap((df_depth_55['MCTSAgent_Smart'],),statistic=np.mean,n_resamples=99999)
#       3 ci_random = result.confidence_interval
#
# NameError: name 'df_depth_55' is not defined

# %%
df_simple = pd.read_csv('results/MCTSAgent-SimpleAgent.csv')
df_random = pd.read_csv('results/MCTSAgent-RandomAgent.csv')
df_highest = pd.read_csv('results/MCTSAgent-HighestAgent.csv')
df_lowest = pd.read_csv('results/MCTSAgent-LowestAgent.csv')
df_smart = pd.read_csv('results/MCTSAgent-SmartAgent.csv')

df_simple['Agent'] = 'Simple'
df_random['Agent'] = 'Random'
df_highest['Agent'] = 'Highest'
df_lowest['Agent'] = 'Lowest'
df_smart['Agent'] = 'Smart'

df_combined_agents = pd.concat([df_simple, df_random, df_highest, df_lowest, df_smart])

mean_scores_agents = df_combined_agents.groupby('Agent')['MCTSAgent'].mean().reset_index()
for i, row in mean_scores_agents.iterrows():
    print(f"Mean for playing against {row['Agent']}: {row['MCTSAgent']:.2f}")

plt.figure(figsize=(10, 6))
plt.bar(mean_scores_agents['Agent'], mean_scores_agents['MCTSAgent'])
plt.title('Average MCTSAgent Scores for Different Agents')
plt.xlabel('Agent')
plt.ylabel('Average MCTSAgent Score')
plt.show()
# Out:
# Mean for playing against Highest: 2.71
# Mean for playing against Lowest: 5.29
# Mean for playing against Random: 3.27
# Mean for playing against Simple: 3.82
# Mean for playing against Smart: 7.25

# %%
data_smart = pd.read_csv("results/MCTSAgent_Smart-SmartAgent.csv")
data_random = pd.read_csv("results/MCTSAgent-SmartAgent.csv")

df = pd.DataFrame({
    'Agent': ['MCTSAgent', 'SmartAgent 1', 'SmartAgent 2', 'SmartAgent 3'],
    'Mean_Score_Smart': [
        data_smart['MCTSAgent_Smart'].mean(),
        data_smart['SmartAgent 1'].mean(),
        data_smart['SmartAgent 2'].mean(),
        data_smart['SmartAgent 3'].mean()],
    'Mean_Score_Random': [
        data_random['MCTSAgent'].mean(),
        data_random['SmartAgent 1'].mean(),
        data_random['SmartAgent 2'].mean(),
        data_random['SmartAgent 3'].mean()]
})

fig, ax = plt.subplots()

df.plot(x='Agent', y=['Mean_Score_Random', 'Mean_Score_Smart'], kind='bar', width=0.4, ax=ax)
ax.legend(['MCTS-Random', 'MCTS-Smart'], loc='lower right')
plt.axhline(y=6.5, color='r', linestyle='-')
plt.title('Mean Scores for MCTS Smart and MCTS Random vs SmartAgent')
plt.axhline(y=6.5, color='r', linestyle='-')
plt.xlabel('Agent')
plt.xticks(rotation=0)
plt.ylabel('Mean Score')
plt.show()

# %%
df_highest_simple = pd.read_csv('results/V2/V2_HighestAgent-SimpleAgent.csv')
df_highest_random = pd.read_csv('results/V2/V2_HighestAgent-RandomAgent.csv')
df_highest_lowest = pd.read_csv('results/V2/V2_HighestAgent-LowestAgent.csv')
df_highest_smart = pd.read_csv('results/V2/V2_HighestAgent-SmartAgent.csv')

df_smart_simple = pd.read_csv('results/V2/V2_SmartAgent-SimpleAgent.csv')

scores_smart_simple = df_smart_simple['SmartAgent']

scores_highest_simple = df_highest_simple['HighestAgent']
scores_highest_random = df_highest_random['HighestAgent']
scores_highest_lowest = df_highest_lowest['HighestAgent']
scores_highest_smart = df_highest_smart['HighestAgent']

plt.figure(1)
plt.hist(scores_highest_simple, bins=13, alpha=0.5,label='Simple Agent', rwidth=0.8)

plt.figure(2)
plt.hist(scores_smart_simple, bins=13, alpha=0.5,label='Simple Agent', rwidth=0.8)
plt.show()
